# %% [markdown]
# # Deck Repair: Batch Cluster Writer
#
# Discovers all `service_page_cluster_*.md` files in `deck-repair/src/data/generated_content/`,
# generates content for every pending subtopic section in each file, and writes results back.
#
# - Files with `status: draft` are skipped automatically
# - Each subtopic receives the **full document** + **Top-K RAG context**
# - References are renumbered globally per file and written to a `## References` table
# - Set `DRY_RUN = True` to preview discovered files without writing

# %%
from pathlib import Path

LANCEDB_PATH = r"C:\Users\tfalcon\microsites\tools\programatic writing stuffs\DBA writer\lancedb_construction_books"
LANCEDB_TABLE = "construction_books"
EMBEDDING_MODEL = "all-MiniLM-L6-v2"
MODEL = "gpt-4o"
TEMPERATURE = 0.7
TOP_K = 20
WORD_TARGET = 200

DRY_RUN = False  # Set True to preview without writing

DECK_REPAIR_DIR = Path("../../../apps/deck-repair/src/data/generated_content")
AGENTS_DIR = Path("../agents")
CONTENT_REVIEW_DIR = Path("../../content-review")

# %%
import sys, os, re
from dotenv import load_dotenv

load_dotenv("../.env")
sys.path.insert(0, str(CONTENT_REVIEW_DIR.resolve()))

import lancedb
from sentence_transformers import SentenceTransformer
from openai import OpenAI
from agent_loader import load_agent

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
embedder = SentenceTransformer(EMBEDDING_MODEL)
db = lancedb.connect(LANCEDB_PATH)
table = db.open_table(LANCEDB_TABLE)
agent = load_agent(AGENTS_DIR / "01-subtopic-writer.md")
print(f"LanceDB: {table.count_rows()} docs | Agent: {agent.name}")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# LanceDB: 6260 docs | Agent: Subtopic Writer

# %%
def parse_stub(path: Path) -> dict:
    """Parse a cluster stub file. Returns dict with keys: path, subtopics, pending, status, service, location."""
    text = path.read_text(encoding="utf-8").replace('\r\n', '\n')

    meta_match = re.search(r'<!--\s*CLUSTER_META([\s\S]*?)-->', text)
    meta = {}
    subtopics = []
    if meta_match:
        in_sub = False
        for line in meta_match.group(1).split('\n'):
            s = line.strip()
            if s.startswith('subtopics:'):
                in_sub = True; continue
            if in_sub:
                if s.startswith('- '): subtopics.append(s[2:].strip())
                elif s and not s.startswith('-'): in_sub = False
            if ':' in s and not in_sub:
                k, v = s.split(':', 1)
                meta[k.strip()] = v.strip()

    pending = [t for t in subtopics if f"## {t}\n*Content to be generated.*" in text]
    return {
        "path": path,
        "subtopics": subtopics,
        "pending": pending,
        "status": meta.get("status", "stub"),
        "service": meta.get("service", "deck repair"),
        "location": meta.get("location", ""),
    }

all_stubs = [parse_stub(p) for p in sorted(DECK_REPAIR_DIR.glob("service_page_cluster_*.md"))]
to_process = [s for s in all_stubs if s["pending"]]
skipped = [s for s in all_stubs if not s["pending"]]

print(f"Found {len(all_stubs)} cluster files")
print(f"  To process : {len(to_process)}")
print(f"  Skip (done): {len(skipped)}")
print()
for s in to_process:
    print(f"  PENDING  {s['path'].name}  ({len(s['pending'])} subtopics)")
for s in skipped:
    print(f"  skip     {s['path'].name}")
# Out:
# Found 14 cluster files
#   To process : 14
#   Skip (done): 0
#
#   PENDING  service_page_cluster_deck-board-repair-replacement_portland.md  (6 subtopics)
#   PENDING  service_page_cluster_deck-board-repair-replacement_seattle.md  (6 subtopics)
#   PENDING  service_page_cluster_deck-ledger-flashing-water-protection_portland.md  (5 subtopics)
#   PENDING  service_page_cluster_deck-ledger-flashing-water-protection_seattle.md  (5 subtopics)
#   PENDING  service_page_cluster_deck-posts-footings-foundation_portland.md  (6 subtopics)
#   PENDING  service_page_cluster_deck-posts-footings-foundation_seattle.md  (6 subtopics)
#   PENDING  service_page_cluster_deck-safety-code-hardware-upgrades_portland.md  (5 subtopics)
#   PENDING  service_page_cluster_deck-safety-code-hardware-upgrades_seattle.md  (5 subtopics)
#   PENDING  service_page_cluster_deck-skirting-lattice-accessories_portland.md  (1 subtopics)
#   PENDING  service_page_cluster_deck-skirting-lattice-accessories_seattle.md  (1 subtopics)
#   PENDING  service_page_cluster_deck-stairs-railings_portland.md  (7 subtopics)
#   PENDING  service_page_cluster_deck-stairs-railings_seattle.md  (7 subtopics)
#   PENDING  service_page_cluster_deck-structural-framing-repair_portland.md  (6 subtopics)
#   PENDING  service_page_cluster_deck-structural-framing-repair_seattle.md  (6 subtopics)

# %%
def generate_subtopic(subtopic: str, doc_text: str, service: str, location_full: str) -> tuple:
    """
    Returns (content_body, ref_rows).
    content_body uses <sup>1</sup>/<sup>2</sup>; ref_rows are pipe-delimited strings.
    """
    query = f"{subtopic} {service} {location_full}"
    results = table.search(embedder.encode([query])[0]).limit(TOP_K).to_pandas()
    rag_context = "\n\n---\n\n".join(
        f"Source: {row.get('source','?')} (Page {row.get('page','N/A')})\n{row['text']}"
        for _, row in results.iterrows()
    )

    user_prompt = f"""## Full document context (understand page scope before writing):

{doc_text}

---

## Construction reference material (RAG):

{rag_context}

---

Write a ~{WORD_TARGET}-word section body for:

Subtopic: {subtopic}
Parent page: {service} — {location_full}

Rules:
- Do NOT include the section heading
- Use <sup>1</sup> and <sup>2</sup> for inline citations
- After the section body, output exactly one line: <!-- REFS -->
- Then output exactly 2 pipe-delimited reference rows (no header row), format:
  | N | Source Title | p. X | Brief note |
- Return nothing else"""

    response = client.chat.completions.create(
        model=MODEL,
        temperature=TEMPERATURE,
        messages=[
            {"role": "system", "content": agent.system_prompt},
            {"role": "user", "content": user_prompt},
        ]
    )
    raw = response.choices[0].message.content.strip()
    parts = raw.split("<!-- REFS -->", 1)
    content_body = parts[0].strip()
    ref_rows = []
    if len(parts) == 2:
        ref_rows = [l.strip() for l in parts[1].strip().splitlines() if l.strip().startswith("|")]
    return content_body, ref_rows


def write_stub(stub: dict, results_store: dict) -> None:
    """Apply generated content and references back to the file."""
    updated = stub["path"].read_text(encoding="utf-8").replace('\r\n', '\n')
    all_ref_rows = []
    global_offset = 0

    for subtopic, (content, refs) in results_store.items():
        # Renumber inline superscripts
        numbered = re.sub(r'<sup>1</sup>', f'<sup>{global_offset + 1}</sup>', content)
        numbered = re.sub(r'<sup>2</sup>', f'<sup>{global_offset + 2}</sup>', numbered)

        # Renumber ref rows
        numbered_refs = []
        for row in refs:
            row = re.sub(r'^\|\s*\d+\s*\|', f'| {global_offset + len(numbered_refs) + 1} |', row)
            numbered_refs.append(row)
        all_ref_rows.extend(numbered_refs)
        global_offset += len(refs)

        placeholder = f"## {subtopic}\n*Content to be generated.*"
        replacement = f"## {subtopic}\n{numbered}"
        updated = updated.replace(placeholder, replacement)

    if all_ref_rows:
        ref_table = (
            "\n## References\n\n"
            "| # | Source | Page | Note |\n"
            "|---|--------|------|------|\n"
            + "\n".join(all_ref_rows) + "\n"
        )
        if "## Page Metadata" in updated:
            updated = updated.replace("## Page Metadata", ref_table + "\n## Page Metadata")
        else:
            updated += ref_table

    updated = re.sub(r'(status:\s*)stub', r'\1draft', updated)
    stub["path"].write_text(updated, encoding="utf-8")

# %%
summary = []  # [(filename, subtopics_written, refs_written)]

for file_i, stub in enumerate(to_process):
    fname = stub["path"].name
    loc = stub["location"]
    location_full = "Portland, Oregon" if loc == "portland" else "Seattle, Washington"

    print(f"\n[{file_i+1}/{len(to_process)}] {fname}")

    # Re-read fresh before each file so doc_text is current
    doc_text = stub["path"].read_text(encoding="utf-8")
    results_store = {}

    for sub_i, subtopic in enumerate(stub["pending"]):
        print(f"  [{sub_i+1}/{len(stub['pending'])}] {subtopic} ...", end=" ", flush=True)
        content, refs = generate_subtopic(subtopic, doc_text, stub["service"], location_full)
        results_store[subtopic] = (content, refs)
        print(f"{len(content.split())} words, {len(refs)} refs")

    total_refs = sum(len(refs) for _, refs in results_store.values())

    if DRY_RUN:
        print(f"  DRY RUN — skipping write ({len(results_store)} sections, {total_refs} refs)")
    else:
        write_stub(stub, results_store)
        print(f"  Written: {len(results_store)} sections, {total_refs} refs")

    summary.append((fname, len(results_store), total_refs))

print("\n" + "="*60)
print("BATCH COMPLETE")
print("="*60)
for fname, secs, refs in summary:
    print(f"  {fname}  →  {secs} sections, {refs} refs")
# Out:
# [1/14] service_page_cluster_deck-board-repair-replacement_portland.md
#   [1/6] Deck Board Removal & Refastening ... 168 words, 2 refs
#   [2/6] Rotten Deck Board Replacement ... 198 words, 2 refs
#   [3/6] Deck Surface Repair & Refinishing ... 162 words, 2 refs
#   [4/6] Touch-Up Sanding & Staining ... 127 words, 2 refs
#   [5/6] Deck Fascia Board Repair ... 192 words, 2 refs
#   [6/6] Deck Rim Joist Repair ... 146 words, 2 refs
#   Written: 6 sections, 12 refs
#
# [2/14] service_page_cluster_deck-board-repair-replacement_seattle.md
#   [1/6] Deck Board Removal & Refastening ... 177 words, 2 refs
#   [2/6] Rotten Deck Board Replacement ... 162 words, 2 refs
#   [3/6] Deck Surface Repair & Refinishing ... 176 words, 2 refs
#   [4/6] Touch-Up Sanding & Staining ... 146 words, 2 refs
#   [5/6] Deck Fascia Board Repair ... 169 words, 2 refs
#   [6/6] Deck Rim Joist Repair ... 136 words, 2 refs
#   Written: 6 sections, 12 refs
#
# [3/14] service_page_cluster_deck-ledger-flashing-water-protection_portland.md
#   [1/5] Deck Ledger Board Replacement ... 171 words, 2 refs
#   [2/5] Deck Ledger Repairs & Flashing ... 190 words, 2 refs
#   [3/5] Deck Flashing Installation or Repair ... 163 words, 2 refs
#   [4/5] Deck Waterproofing Repairs ... 148 words, 2 refs
#   [5/5] Deck Drainage Corrections ... 167 words, 2 refs
#   Written: 5 sections, 10 refs
#
# [4/14] service_page_cluster_deck-ledger-flashing-water-protection_seattle.md
#   [1/5] Deck Ledger Board Replacement ... 183 words, 2 refs
#   [2/5] Deck Ledger Repairs & Flashing ... 184 words, 2 refs
#   [3/5] Deck Flashing Installation or Repair ... 162 words, 2 refs
#   [4/5] Deck Waterproofing Repairs ... 139 words, 2 refs
#   [5/5] Deck Drainage Corrections ... 139 words, 2 refs
#   Written: 5 sections, 10 refs
#
# [5/14] service_page_cluster_deck-posts-footings-foundation_portland.md
#   [1/6] Deck Post Replacement ... 162 words, 2 refs
#   [2/6] Footing Repairs & Replacement ... 143 words, 2 refs
#   [3/6] Deck Concrete Pier Repair ... 154 words, 2 refs
#   [4/6] Deck Shoring & Safety ... 163 words, 2 refs
#   [5/6] Deck Leveling & Stabilization ... 160 words, 2 refs
#   [6/6] Deck Support Post Repair ... 161 words, 2 refs
#   Written: 6 sections, 12 refs
#
# [6/14] service_page_cluster_deck-posts-footings-foundation_seattle.md
#   [1/6] Deck Post Replacement ... 157 words, 2 refs
#   [2/6] Footing Repairs & Replacement ... 156 words, 2 refs
#   [3/6] Deck Concrete Pier Repair ... 167 words, 2 refs
#   [4/6] Deck Shoring & Safety ... 147 words, 2 refs
#   [5/6] Deck Leveling & Stabilization ... 149 words, 2 refs
#   [6/6] Deck Support Post Repair ... 156 words, 2 refs
#   Written: 6 sections, 12 refs
#
# [7/14] service_page_cluster_deck-safety-code-hardware-upgrades_portland.md
#   [1/5] Deck Safety Upgrades to Current Code ... 172 words, 2 refs
#   [2/5] Deck Hardware Replacement ... 154 words, 2 refs
#   [3/5] Deck Connector Upgrades (Simpson Hardware) ... 126 words, 2 refs
#   [4/5] Joist Hanger Repairs or Upgrades ... 131 words, 2 refs
#   [5/5] Deck Structural Reinforcement ... 137 words, 2 refs
#   Written: 5 sections, 10 refs
#
# [8/14] service_page_cluster_deck-safety-code-hardware-upgrades_seattle.md
#   [1/5] Deck Safety Upgrades to Current Code ... 159 words, 2 refs
#   [2/5] Deck Hardware Replacement ... 140 words, 2 refs
#   [3/5] Deck Connector Upgrades (Simpson Hardware) ... 177 words, 2 refs
#   [4/5] Joist Hanger Repairs or Upgrades ... 150 words, 2 refs
#   [5/5] Deck Structural Reinforcement ... 160 words, 2 refs
#   Written: 5 sections, 10 refs
#
# [9/14] service_page_cluster_deck-skirting-lattice-accessories_portland.md
#   [1/1] Deck Skirting or Lattice Repair ... 142 words, 2 refs
#   Written: 1 sections, 2 refs
#
# [10/14] service_page_cluster_deck-skirting-lattice-accessories_seattle.md
#   [1/1] Deck Skirting or Lattice Repair ... 147 words, 2 refs
#   Written: 1 sections, 2 refs
#
# [11/14] service_page_cluster_deck-stairs-railings_portland.md
#   [1/7] Deck Stair Stringer Repair ... 179 words, 2 refs
#   [2/7] Deck Stair Tread Replacement ... 189 words, 2 refs
#   [3/7] Staircase Repairs ... 140 words, 2 refs
#   [4/7] Deck Railing Repair or Replacement ... 172 words, 2 refs
#   [5/7] Handrail Repair ... 169 words, 2 refs
#   [6/7] Deck Guardrail Repair ... 163 words, 2 refs
#   [7/7] Deck Baluster Replacement ... 161 words, 2 refs
#   Written: 7 sections, 14 refs
#
# [12/14] service_page_cluster_deck-stairs-railings_seattle.md
#   [1/7] Deck Stair Stringer Repair ... 160 words, 2 refs
#   [2/7] Deck Stair Tread Replacement ... 164 words, 2 refs
#   [3/7] Staircase Repairs ... 139 words, 2 refs
#   [4/7] Deck Railing Repair or Replacement ... 159 words, 2 refs
#   [5/7] Handrail Repair ... 162 words, 2 refs
#   [6/7] Deck Guardrail Repair ... 149 words, 2 refs
#   [7/7] Deck Baluster Replacement ... 163 words, 2 refs
#   Written: 7 sections, 14 refs
#
# [13/14] service_page_cluster_deck-structural-framing-repair_portland.md
#   [1/6] Deck Joist Repair & Replacement ... 157 words, 2 refs
#   [2/6] Deck Beam Replacement ... 189 words, 2 refs
#   [3/6] Post & Beam Repairs ... 195 words, 2 refs
#   [4/6] Deck Bracing & Structural Framing ... 159 words, 2 refs
#   [5/6] Deck Blocking Installation ... 148 words, 2 refs
#   [6/6] Deck Framing Repair & Reinforcement ... 154 words, 2 refs
#   Written: 6 sections, 12 refs
#
# [14/14] service_page_cluster_deck-structural-framing-repair_seattle.md
#   [1/6] Deck Joist Repair & Replacement ... 154 words, 2 refs
#   [2/6] Deck Beam Replacement ... 169 words, 2 refs
#   [3/6] Post & Beam Repairs ... 167 words, 2 refs
#   [4/6] Deck Bracing & Structural Framing ... 144 words, 2 refs
#   [5/6] Deck Blocking Installation ... 156 words, 2 refs
#   [6/6] Deck Framing Repair & Reinforcement ... 150 words, 2 refs
#   Written: 6 sections, 12 refs
#
# ============================================================
# BATCH COMPLETE
# ============================================================
#   service_page_cluster_deck-board-repair-replacement_portland.md  →  6 sections, 12 refs
#   service_page_cluster_deck-board-repair-replacement_seattle.md  →  6 sections, 12 refs
#   service_page_cluster_deck-ledger-flashing-water-protection_portland.md  →  5 sections, 10 refs
#   service_page_cluster_deck-ledger-flashing-water-protection_seattle.md  →  5 sections, 10 refs
#   service_page_cluster_deck-posts-footings-foundation_portland.md  →  6 sections, 12 refs
#   service_page_cluster_deck-posts-footings-foundation_seattle.md  →  6 sections, 12 refs
#   service_page_cluster_deck-safety-code-hardware-upgrades_portland.md  →  5 sections, 10 refs
#   service_page_cluster_deck-safety-code-hardware-upgrades_seattle.md  →  5 sections, 10 refs
#   service_page_cluster_deck-skirting-lattice-accessories_portland.md  →  1 sections, 2 refs
#   service_page_cluster_deck-skirting-lattice-accessories_seattle.md  →  1 sections, 2 refs
#   service_page_cluster_deck-stairs-railings_portland.md  →  7 sections, 14 refs
#   service_page_cluster_deck-stairs-railings_seattle.md  →  7 sections, 14 refs
#   service_page_cluster_deck-structural-framing-repair_portland.md  →  6 sections, 12 refs
#   service_page_cluster_deck-structural-framing-repair_seattle.md  →  6 sections, 12 refs
